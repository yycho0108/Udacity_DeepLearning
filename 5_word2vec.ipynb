# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.296905
# Nearest to a: innings, shulkhan, mcvie, beetles, ninth, bekenstein, berber, redneck,
# Nearest to over: kq, multiply, lderlin, station, claymore, bangkok, shanghainese, pathological,
# Nearest to during: galvanic, partitioning, equivalent, athenaeus, bouts, unsuspecting, showings, blvd,
# Nearest to they: polybius, increments, commander, urchin, relinquishing, squares, godless, archon,
# Nearest to often: sutter, praising, lumbar, gaon, nihilist, symbolizing, addison, dysprosium,
# Nearest to may: smitten, glitter, cents, terraced, prophetess, appeared, hark, magnetron,
# Nearest to the: renouf, euripides, bahri, spreading, emails, ashkenazim, umbrella, impious,
# Nearest to from: expose, shale, gao, visitation, aegis, soles, ther, predicament,
# Nearest to can: antioch, computed, osr, resulting, puppet, wallis, plugged, illusory,
# Nearest to and: chr, cryobiology, shaka, patsy, kwanzaa, felis, hjalmar, rucker,
# Nearest to were: commute, hulk, diaspora, rightly, br, reassembled, opposed, veto,
# Nearest to after: tombaugh, translators, lenny, premiere, arts, comp, int, boswell,
# Nearest to so: diagonals, screenplays, rail, powerful, circ, visible, sergius, stadia,
# Nearest to his: deuteronomic, taunton, y, orthogonality, must, finiteness, affiliate, greeks,
# Nearest to more: carriers, megaliths, endorse, puerto, hieroglyphs, hawking, marcelo, scarred,
# Nearest to state: kuti, barclay, lasor, techniques, platonic, awm, oneida, elrond,
# Average loss at step 2000: 4.350158
# Average loss at step 4000: 3.864244
# Average loss at step 6000: 3.791050
# Average loss at step 8000: 3.685019
# Average loss at step 10000: 3.615249
# Nearest to a: the, dunham, any, this, prestigious, his, their, its,
# Nearest to over: station, daoxuan, multiply, slips, declines, devils, pathological, claymore,
# Nearest to during: galvanic, bouts, athenaeus, curds, coppersmith, agrippa, first, crazed,
# Nearest to they: we, he, it, yevgeny, not, roast, moritz, there,
# Nearest to often: it, also, usually, gaon, sometimes, there, lifting, we,
# Nearest to may: can, appeared, will, lisp, hansen, riigikogu, cents, might,
# Nearest to the: a, his, its, this, an, their, uber, remit,
# Nearest to from: in, by, expose, on, milliardo, stirling, iq, into,
# Nearest to can: would, may, might, could, should, will, akihabara, computed,
# Nearest to and: or, on, against, verbs, american, who, kofi, halved,
# Nearest to were: are, was, have, had, commute, loading, be, bombs,
# Nearest to after: premiere, pareto, as, supplement, mathers, glyn, cryopreserved, grote,
# Nearest to so: diagonals, malevich, affricate, screenplays, damping, diffused, found, visible,
# Nearest to his: the, its, their, her, s, a, reproach, turning,
# Nearest to more: josef, meteorologists, cannes, steam, inversions, amines, puerto, viewed,
# Nearest to state: incubus, satsuma, cq, techniques, lasor, authorized, stylus, barclay,
# Average loss at step 12000: 3.607420
# Average loss at step 14000: 3.571178
# Average loss at step 16000: 3.408445
# Average loss at step 18000: 3.460574
# Average loss at step 20000: 3.538000
# Nearest to a: any, the, dunham, this, frustrating, photovoltaic, tamer, carta,
# Nearest to over: station, devils, daoxuan, multiply, peers, advancing, nash, slips,
# Nearest to during: after, under, curds, galvanic, in, concrete, crazed, coppersmith,
# Nearest to they: we, he, there, it, not, you, roast, who,
# Nearest to often: usually, also, sometimes, lifting, there, it, we, serious,
# Nearest to may: can, would, might, will, could, cannot, should, appeared,
# Nearest to the: their, this, its, mitsubishi, a, his, preferably, any,
# Nearest to from: in, after, at, into, through, for, on, and,
# Nearest to can: would, may, should, could, might, will, cannot, must,
# Nearest to and: or, but, in, including, gabonese, which, at, from,
# Nearest to were: are, was, had, have, loading, been, be, navajo,
# Nearest to after: from, during, with, before, reflexive, wawel, prices, cryopreserved,
# Nearest to so: diagonals, visible, malevich, delegated, refresh, damping, pcd, dead,
# Nearest to his: their, her, its, fdl, the, reproach, dictating, many,
# Nearest to more: very, solitary, less, amines, most, josef, cartels, meteorologists,
# Nearest to state: cq, incubus, satsuma, atahualpa, barclay, lasor, liberian, systematic,
# Average loss at step 22000: 3.501878
# Average loss at step 24000: 3.492253
# Average loss at step 26000: 3.476697
# Average loss at step 28000: 3.475895
# Average loss at step 30000: 3.505068
# Nearest to a: any, the, no, another, repeatedly, studios, too, tents,
# Nearest to over: peers, daoxuan, declines, station, franke, discrimination, elevates, hence,
# Nearest to during: after, in, under, from, when, at, concrete, succumbing,
# Nearest to they: we, there, he, it, you, who, not, these,
# Nearest to often: usually, sometimes, also, lifting, commonly, there, generally, still,
# Nearest to may: can, would, could, will, might, should, cannot, must,
# Nearest to the: their, its, his, a, clausewitz, her, internetworking, any,
# Nearest to from: into, through, after, on, during, aegis, in, under,
# Nearest to can: may, would, could, should, will, cannot, must, might,
# Nearest to and: or, but, against, s, punjabi, including, in, of,
# Nearest to were: are, was, have, had, been, br, be, although,
# Nearest to after: before, during, from, when, reflexive, wawel, under, cryopreserved,
# Nearest to so: shark, damping, visible, malevich, celia, too, refresh, diagonals,
# Nearest to his: her, their, its, the, s, reproach, fdl, dictating,
# Nearest to more: less, very, most, rather, marcelo, solitary, larger, josef,
# Nearest to state: cq, states, barclay, satsuma, liberian, guardianship, atahualpa, incubus,
# Average loss at step 32000: 3.495078
# Average loss at step 34000: 3.493844
# Average loss at step 36000: 3.452868
# Average loss at step 38000: 3.303453
# Average loss at step 40000: 3.429352
# Nearest to a: cde, any, or, another, the, no, correcting, dunham,
# Nearest to over: within, daoxuan, copula, specter, marinus, elihu, revisionism, through,
# Nearest to during: after, in, under, since, at, before, succumbing, netherlands,
# Nearest to they: we, there, he, you, it, i, she, these,
# Nearest to often: usually, sometimes, commonly, also, generally, still, which, who,
# Nearest to may: can, could, will, would, might, should, cannot, must,
# Nearest to the: its, their, his, this, each, any, a, dunham,
# Nearest to from: into, through, after, in, virginals, bungalow, on, of,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to and: but, or, fmln, lowercase, crumbled, kofi, from, sipe,
# Nearest to were: are, have, was, be, had, been, navajo, although,
# Nearest to after: before, during, when, from, reflexive, with, while, wawel,
# Nearest to so: celia, maelstrom, too, delegated, then, visible, ternary, refresh,
# Nearest to his: their, her, its, my, the, s, your, reproach,
# Nearest to more: most, less, very, rather, metric, solitary, larger, matrimony,
# Nearest to state: barclay, government, cq, atahualpa, kenya, benefit, states, stylus,
# Average loss at step 42000: 3.434362
# Average loss at step 44000: 3.453164
# Average loss at step 46000: 3.448937
# Average loss at step 48000: 3.352753
# Average loss at step 50000: 3.379995
# Nearest to a: any, the, another, no, shrunk, repeatedly, cylinder, dug,
# Nearest to over: through, elihu, fukuoka, within, marinus, station, revisionism, copula,
# Nearest to during: after, in, when, under, at, from, since, before,
# Nearest to they: we, there, he, you, it, she, these, not,
# Nearest to often: usually, sometimes, commonly, generally, now, frequently, still, also,
# Nearest to may: can, could, would, will, might, should, must, cannot,
# Nearest to the: its, their, this, a, qam, his, clausewitz, injustice,
# Nearest to from: through, into, during, in, after, virginals, grenoble, at,
# Nearest to can: could, may, would, will, should, must, might, cannot,
# Nearest to and: or, but, in, of, expendable, veiled, while, including,
# Nearest to were: are, was, have, had, been, although, superluminal, be,
# Nearest to after: before, when, during, while, from, since, reflexive, wawel,
# Nearest to so: then, too, foreseen, malevich, capella, refresh, bashing, centrifugal,
# Nearest to his: her, their, its, my, your, reproach, the, s,
# Nearest to more: less, most, very, rather, quite, matrimony, metric, dementia,
# Nearest to state: benefit, barclay, cq, kenya, alphabetic, government, states, trumped,
# Average loss at step 52000: 3.436357
# Average loss at step 54000: 3.429785
# Average loss at step 56000: 3.434002
# Average loss at step 58000: 3.396636
# Average loss at step 60000: 3.388445
# Nearest to a: another, any, the, mair, cylinder, this, confessor, redactor,
# Nearest to over: through, within, into, throughout, in, duelling, around, marinus,
# Nearest to during: after, in, before, throughout, when, since, although, despite,
# Nearest to they: we, there, you, he, she, it, these, earthworm,
# Nearest to often: sometimes, usually, commonly, generally, now, also, still, frequently,
# Nearest to may: can, could, would, will, might, must, should, cannot,
# Nearest to the: their, its, a, this, some, any, these, hippos,
# Nearest to from: through, into, under, in, fury, after, on, virginals,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to and: or, but, than, including, while, dirt, without, expendable,
# Nearest to were: are, was, have, those, had, been, superluminal, although,
# Nearest to after: before, during, when, while, following, since, although, wawel,
# Nearest to so: too, ternary, then, dead, foreseen, gardening, maelstrom, refresh,
# Nearest to his: her, their, its, my, your, reproach, our, fdl,
# Nearest to more: less, most, larger, very, rather, abyss, quite, matrimony,
# Nearest to state: cq, states, benefit, government, alphabetic, federal, group, branches,
# Average loss at step 62000: 3.238916
# Average loss at step 64000: 3.256391
# Average loss at step 66000: 3.400672
# Average loss at step 68000: 3.394086
# Average loss at step 70000: 3.356474
# Nearest to a: another, dunham, the, any, otter, tamer, omri, wrongful,
# Nearest to over: within, through, hence, throughout, fukuoka, copula, donors, monos,
# Nearest to during: after, in, before, throughout, through, under, within, since,
# Nearest to they: we, there, he, you, it, she, these, wiring,
# Nearest to often: usually, sometimes, commonly, generally, now, still, frequently, widely,
# Nearest to may: can, could, would, will, might, must, should, cannot,
# Nearest to the: their, its, this, any, a, these, each, our,
# Nearest to from: through, into, in, under, across, aegis, between, dialysis,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to and: or, but, which, while, of, including, however, like,
# Nearest to were: are, was, had, have, be, been, dieter, these,
# Nearest to after: before, during, when, while, through, following, from, empress,
# Nearest to so: too, thus, gardening, foreseen, maelstrom, dead, then, malevich,
# Nearest to his: her, their, its, my, your, our, fdl, the,
# Nearest to more: less, most, larger, very, rather, quite, matrimony, grotesque,
# Nearest to state: states, government, kenya, city, cq, federal, instructors, alphabetic,
# Average loss at step 72000: 3.372799
# Average loss at step 74000: 3.350169
# Average loss at step 76000: 3.310320
# Average loss at step 78000: 3.350930
# Average loss at step 80000: 3.381493
# Nearest to a: the, dunham, another, any, taxable, otter, wrongful, cylinder,
# Nearest to over: within, through, around, throughout, peers, into, revisionism, donors,
# Nearest to during: after, in, despite, before, throughout, when, through, under,
# Nearest to they: we, he, there, you, it, she, these, not,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, still, widely,
# Nearest to may: can, might, could, would, will, should, must, cannot,
# Nearest to the: its, a, their, his, qam, this, injustice, endow,
# Nearest to from: through, into, in, across, by, under, during, dialysis,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to and: or, but, while, including, colloquium, until, on, although,
# Nearest to were: are, had, was, have, been, be, those, being,
# Nearest to after: before, during, when, while, despite, following, at, later,
# Nearest to so: too, then, maelstrom, foreseen, bournemouth, dead, capella, centrifugal,
# Nearest to his: her, their, my, its, your, our, the, personal,
# Nearest to more: less, most, very, larger, quite, rather, extremely, higher,
# Nearest to state: states, city, government, cq, atahualpa, predate, kenya, alphabetic,
# Average loss at step 82000: 3.405888
# Average loss at step 84000: 3.410198
# Average loss at step 86000: 3.387210
# Average loss at step 88000: 3.350403
# Average loss at step 90000: 3.361768
# Nearest to a: condemns, the, any, another, taxable, dunham, fic, hammersmith,
# Nearest to over: through, within, around, throughout, off, before, revisionism, peers,
# Nearest to during: after, in, before, through, throughout, despite, at, while,
# Nearest to they: we, he, you, there, she, it, but, these,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, also, still,
# Nearest to may: can, could, should, would, might, will, must, cannot,
# Nearest to the: its, this, their, his, a, any, qam, another,
# Nearest to from: through, into, across, during, under, virginals, keiretsu, after,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to and: or, but, while, including, of, although, inflows, however,
# Nearest to were: are, was, had, have, those, while, dieter, these,
# Nearest to after: before, during, when, while, despite, following, through, until,
# Nearest to so: too, thus, foreseen, dead, centrifugal, then, if, caine,
# Nearest to his: her, their, its, your, my, our, reproach, the,
# Nearest to more: less, most, quite, very, larger, rather, extremely, greater,
# Nearest to state: city, states, government, haymarket, alphabetic, paleolithic, instructors, invisibly,
# Average loss at step 92000: 3.391254
# Average loss at step 94000: 3.254378
# Average loss at step 96000: 3.357119
# Average loss at step 98000: 3.240583
# Average loss at step 100000: 3.355789
# Nearest to a: any, another, taxable, the, fic, hammersmith, salic, spore,
# Nearest to over: through, within, revisionism, around, into, before, dilution, monos,
# Nearest to during: in, after, throughout, through, before, despite, since, at,
# Nearest to they: we, he, there, you, she, it, i, these,
# Nearest to often: sometimes, usually, generally, commonly, frequently, now, typically, widely,
# Nearest to may: can, could, should, might, must, would, will, cannot,
# Nearest to the: their, its, his, your, a, this, her, each,
# Nearest to from: into, in, through, across, during, virginals, keiretsu, rehoboam,
# Nearest to can: could, may, will, must, should, would, cannot, might,
# Nearest to and: or, but, although, however, including, while, when, oaxaca,
# Nearest to were: are, have, was, these, had, those, reis, include,
# Nearest to after: before, during, when, following, without, while, despite, through,
# Nearest to so: thus, too, when, then, foreseen, if, naturally, centrifugal,
# Nearest to his: her, their, my, your, our, its, the, s,
# Nearest to more: less, most, larger, quite, very, greater, rather, extremely,
# Nearest to state: city, states, paleolithic, haymarket, government, instructors, alphabetic, predate,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
